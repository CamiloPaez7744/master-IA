# %%
pip install openai

# %% [markdown]
# # Ejemplo con OpenAI GPT-OSS

# %%
import os
from openai import OpenAI
from google.colab import userdata

# Access the Hugging Face API key from Colab Secrets Manager
# Make sure you've added your key with the name 'HF_API_KEY'
hf_api_key = userdata.get("HF_TOKEN")

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=hf_api_key,
)

completion = client.chat.completions.create(
    model="openai/gpt-oss-120b:cerebras",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The capital of France is **Paris**.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning='User asks simple question: capital of France is Paris. Answer straightforward.')

# %% [markdown]
# # Ejemplo con DeepSeek v3.2

# %%
import os
from openai import OpenAI
from google.colab import userdata


hf_api_key = userdata.get("HF_TOKEN")

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=hf_api_key,
)

completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-V3.2-Exp",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The capital of France is **Paris**.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)
