# %% [markdown]
# # Uso de Whisper

# %%
import os
from huggingface_hub import InferenceClient
from google.colab import userdata

client = InferenceClient(
    provider="hf-inference",
    api_key=userdata.get("HF_TOKEN"),
)

output = client.automatic_speech_recognition("audio_prueba.wav", model="openai/whisper-large-v3")

# %%
print(output)
# Out:
# AutomaticSpeechRecognitionOutput(text=' Hola, esto es una prueba para que en el curso veáis cómo se puede transcribir un audio.', chunks=None)
